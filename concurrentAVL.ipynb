# %% [markdown]
# Sequential AVL Tree
#
# Reference (Chinese): https://www.cnblogs.com/skywang12345/p/3576969.html

# %%
from pyConAVL import ConAVL
import random

# %%
tree = ConAVL()
for i in range(1,21):
    if i%2 == 0:
        tree.put(i)
tree.print()
tree.put(12, "abc")
tree.print()
tree.remove(16)
tree.remove(20)
tree.remove(18)
tree.print()
# Out:
# removal!
# removal!
# removal!

# %%
tree.root.version

# %%
v = Version()
w = Version()
v.unlinked = True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-44c486bb91fc> in <module>()
# ----> 1 v = Version()
#       2 w = Version()
#       3 v.unlinked = True
#
# NameError: name 'Version' is not defined

# %%
v!=w

# %%
tree = ConAVL()
ltp = random.sample(list(range(100)),k=100)
for i in ltp:
#     print(i)
    tree.put(i)
tree.print()

# %%
balanceCheck(tree.root)
