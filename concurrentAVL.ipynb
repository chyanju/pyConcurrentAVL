# %% [markdown]
# Sequential AVL Tree
#
# Reference (Chinese): https://www.cnblogs.com/skywang12345/p/3576969.html

# %%
from pyConAVL import ConAVL
import random
import threading

# %%
ltp = random.sample(list(range(50)),k=50)

# %%
def insert(l, tree):
    for i in l:
        tree.put(i)
tree = ConAVL()
tpool = []
for i in range(5):
    tpool.append(threading.Thread(target=insert,args=(ltp[i*10:(i+1)*10],tree)))
for i in range(5):
    tpool[i].start()
for i in range(5):
    tpool[i].join()
tree.print()

# %%
def insert(l, tree):
    for i in l:
        tree.put(i)

dtree = ConAVL()
ltp = [92, 74, 66, 35, 29, 38, 52, 22, 30, 68, 32, 99, 48, 39, 7, 8, 33, 81, 67, 26]
# ltp = [92, 74, 66, 35]
tpool = []
insert(ltp[0:9],dtree)
    
dtree.print()

# %%
def insert(tree):
    for i in range(5):
        tree.put(i)
        
    for i in range(15, 20):
        tree.put(i)
    
def insert2(tree):
    for i in reversed(range(5, 15)):
        tree.put(i)


# tree = AVL()
ctree = ConAVL()
        

insert(ctree)
ctree.print()
insert2(ctree)
ctree.print()
# ctree.put(14)
# ctree.print()
# ctree.put(13)
# ctree.print()
# # ctree.put(12)
# # ctree.print()
# # ctree.put(11)
# # ctree.print()
# # ctree.put(10)
# # ctree.print()
# # ctree.put(9)
# # ctree.print()
# # ctree.put(8)
# # ctree.print()
# # ctree.put(7)
# # ctree.print()
# # ctree.put(6)
# # ctree.print()
# # ctree.put(5)
# # ctree.print()
# Out:
# None
# None
# 0
# 0
# -2
# rebalance node 0
# ola
# rebalance left 0
# 1
# 1
# 3
# 2
# 2
# -2
# rebalance node 2
# ola
# rebalance left 2
# 3
# 3
# 3
# -2
# rebalance node 1
# ola
# rebalance left 1
# 4
# 4
# -2
# rebalance node 4
# ola
# rebalance left 4
# 15
# 15
# 3
# 4
# 16
# 16
# -2
# rebalance node 16
# ola
# rebalance left 16
# 17
# 17
# 3
# -2
# rebalance node 15
# ola
# rebalance left 15
# 15
# 15
# 3
# 4
# -2
# rebalance node 3
# ola
# rebalance left 3
# muito perto!
# 4
# 4
# -2
# rebalance node 4
# ola
# rebalance left 4
# muito perto!
# 13
# 13
# 3
# 4
# 5
# 4
# 4
# -2
# rebalance node 4
# ola
# rebalance left 4
# muito perto!
# 11
# 11
# 3
# -2
# rebalance node 13
# 4
# 4
# -2
# rebalance node 4
# ola
# rebalance left 4
# muito perto!
# 9
# 9
# 3
# 4
# -2
# rebalance node 3
# ola
# rebalance left 3
# muito perto!
# 4
# 4
# -2
# rebalance node 4
# ola
# rebalance left 4
# muito perto!
# 7
# 7
# 3
# 4
# 5
# -2
# rebalance node 15
# 4
# 4
# -2
# rebalance node 4
# ola
# ...

# %%
tree.root.version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7b1eebf2ceea> in <module>()
# ----> 1 tree.root.version
#
# NameError: name 'tree' is not defined

# %%
v = Version()
w = Version()
v.unlinked = True

# %%
v!=w

# %%
tree = ConAVL()
ltp = random.sample(list(range(100)),k=100)
for i in ltp:
#     print(i)
    tree.put(i)
tree.print()

# %%
balanceCheck(tree.root)
